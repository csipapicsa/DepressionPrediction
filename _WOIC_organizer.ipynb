# %% [markdown]
# ### Daic woz df makerí

# %%
import pandas as pd
import os
from functions_data_prep import *

# %%
BASE_PATH = "datasets/DAIC-WOZ/"
files = os.listdir(BASE_PATH+"/cuts")
df_train = pd.read_csv(BASE_PATH + "train_split_Depression_AVEC2017.csv")
df_dev = pd.read_csv(BASE_PATH + "dev_split_Depression_AVEC2017.csv")

# %%
# merge together the df_train and df_dev. df_train dataset column = 'trian' df_dev dataset column = 'dev'
df_train['dataset'] = 'train'
df_dev['dataset'] = 'dev'
df = pd.concat([df_train, df_dev])

# %%
df["PHQ8_multiclass"] = phq8_to_multiclass(df["PHQ8_Score"])

# %%
df
# Out:
#     Participant_ID  PHQ8_Binary  PHQ8_Score  Gender  PHQ8_NoInterest  \
# 0              303            0           0       0                0
# 1              304            0           6       0                0
# 2              305            0           7       1                0
# 3              310            0           4       1                1
# 4              312            0           2       1                0
# ..             ...          ...         ...     ...              ...
# 30             483            1          15       1                0
# 31             484            0           9       0                1
# 32             489            0           3       1                0
# 33             490            0           2       1                0
# 34             492            0           0       0                0
#
#     PHQ8_Depressed  PHQ8_Sleep  PHQ8_Tired  PHQ8_Appetite  PHQ8_Failure  \
# ...

# %%
df = df[['Participant_ID', 'PHQ8_Binary', 'PHQ8_Score', 'PHQ8_multiclass', 'dataset']]

# %%
df.to_csv(BASE_PATH + "Patient_Classes.csv", index=False)
